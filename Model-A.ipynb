# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import RFE
import itertools
import time
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from sklearn.model_selection import cross_val_score
from tabulate import tabulate
import optuna
from joblib import dump
from joblib import load

# %% [markdown]
# #### Data Loading and Initial Exploration

# %%
# load Train data
train_data = pd.read_csv('/Users/maryam/ML-IDS/Dataset/Train_data.csv')
# load Test data
test_data = pd.read_csv('/Users/maryam/ML-IDS/Dataset/Test_data.csv')

# %%
# we will use the following features to train our model
train_data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate    class
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  anomaly
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
# we will use the following features to test our model
test_data.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0               0       0    0  ...             255                  10
# 1               0       0    0  ...             255                   1
# 2               0       0    0  ...             134                  86
# 3               0       0    0  ...               3                  57
# 4               0       0    0  ...              29                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate
# 0                      1.00
# 1                      1.00
# 2                      0.00
# 3                      0.00
# 4                      0.71
#
# [5 rows x 41 columns]

# %%
# General information and statistics about the train data
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25192 entries, 0 to 25191
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     25192 non-null  int64
#  1   protocol_type                25192 non-null  object
#  2   service                      25192 non-null  object
#  3   flag                         25192 non-null  object
#  4   src_bytes                    25192 non-null  int64
#  5   dst_bytes                    25192 non-null  int64
#  6   land                         25192 non-null  int64
#  7   wrong_fragment               25192 non-null  int64
#  8   urgent                       25192 non-null  int64
#  9   hot                          25192 non-null  int64
#  10  num_failed_logins            25192 non-null  int64
#  11  logged_in                    25192 non-null  int64
#  12  num_compromised              25192 non-null  int64
#  13  root_shell                   25192 non-null  int64
#  14  su_attempted                 25192 non-null  int64
#  15  num_root                     25192 non-null  int64
#  16  num_file_creations           25192 non-null  int64
#  17  num_shells                   25192 non-null  int64
#  18  num_access_files             25192 non-null  int64
#  19  num_outbound_cmds            25192 non-null  int64
#  20  is_host_login                25192 non-null  int64
#  21  is_guest_login               25192 non-null  int64
#  22  count                        25192 non-null  int64
#  23  srv_count                    25192 non-null  int64
#  24  serror_rate                  25192 non-null  float64
#  25  srv_serror_rate              25192 non-null  float64
#  26  rerror_rate                  25192 non-null  float64
#  27  srv_rerror_rate              25192 non-null  float64
#  28  same_srv_rate                25192 non-null  float64
#  29  diff_srv_rate                25192 non-null  float64
#  30  srv_diff_host_rate           25192 non-null  float64
#  31  dst_host_count               25192 non-null  int64
#  32  dst_host_srv_count           25192 non-null  int64
#  33  dst_host_same_srv_rate       25192 non-null  float64
#  34  dst_host_diff_srv_rate       25192 non-null  float64
#  35  dst_host_same_src_port_rate  25192 non-null  float64
#  36  dst_host_srv_diff_host_rate  25192 non-null  float64
#  37  dst_host_serror_rate         25192 non-null  float64
#  38  dst_host_srv_serror_rate     25192 non-null  float64
#  39  dst_host_rerror_rate         25192 non-null  float64
#  40  dst_host_srv_rerror_rate     25192 non-null  float64
#  41  class                        25192 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 8.1+ MB

# %%
# describe the train data
train_data.describe(include='object')
# Out:
#        protocol_type service   flag   class
# count          25192   25192  25192   25192
# unique             3      66     11       2
# top              tcp    http     SF  normal
# freq           20526    8003  14973   13449

# %%
train_data.protocol_type.unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %% [markdown]
# #### Data Cleaning and Preprocessing

# %%
# Checking for missing values and duplicates
missing_values = train_data.isnull().sum()
total = train_data.shape[0]
missing_columns = [col for col in train_data.columns if train_data[col].isnull().sum() > 0]
for col in missing_columns:
    null_count = train_data[col].isnull().sum()
    per = (null_count/total) * 100
    print(f"{col}: {null_count} ({round(per, 3)}%)")

# %%
# Checking for duplicate rows
print(f"Number of duplicate rows: {train_data.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0

# %%
# Class distribution in Training set

sns.countplot(x=train_data['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
print('Class distribution Training set:')
print(train_data['class'].value_counts())
# Out:
# Class distribution Training set:
# normal     13449
# anomaly    11743
# Name: class, dtype: int64

# %%
# Encoding categorical features
def label_encode(df):
    for col in df.columns:
        if df[col].dtype == 'object':
            label_encoder = LabelEncoder()
            df[col] = label_encoder.fit_transform(df[col])

label_encode(train_data)
label_encode(test_data)

# %%
# why drop this column?
# The column num_outbound_cmds has only one unique value, so it is not useful for our model
train_data.drop(['num_outbound_cmds'], axis=1, inplace=True)
test_data.drop(['num_outbound_cmds'], axis=1, inplace=True)
# drop hot column
train_data.drop(['hot'], axis=1, inplace=True)
test_data.drop(['hot'], axis=1, inplace=True)

# %% [markdown]
# #### Feature Selection and Normalization

# %%
# Splitting data into features and target
X_train = train_data.drop(['class'], axis=1)
Y_train = train_data['class']

# %%
# What is happening in this code
# Random Forest Classifier is used to rank the importance of features
# RFE is used to select the most important features
# we will use 5 features in our model
# we will use the selected features to train our model
# we will use the selected features to test our model

# Feature selection using Random Forest Classifier
rfc = DecisionTreeClassifier()  # Using Decision Tree for feature selection
rfe = RFE(rfc, n_features_to_select=5)
rfe = rfe.fit(X_train, Y_train)

# Selecting important features
feature_map = [(i, v) for i, v in itertools.zip_longest(rfe.get_support(), X_train.columns)]
selected_features = [v for i, v in feature_map if i==True]
selected_features
# Out:
# ['protocol_type',
#  'src_bytes',
#  'dst_bytes',
#  'dst_host_srv_count',
#  'dst_host_same_srv_rate']

# %%
# Train data with selected features
X_train = X_train[selected_features]

# %%
# Scaling features why? and what is the purpose of scaling?
# Scaling is used to standardize the range of independent variables or features of the data
# StandardScaler is used to scale the features
# we will use the scaled features to train our model
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
test = scale.fit_transform(test_data)

# %%
# Splitting the dataset for training and testing
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, train_size=0.70, random_state=42)

# %% [markdown]
# #### Decision Tree Model Training and Tuning

# %%
# Training a basic Decision Tree Classifier
# Time to train the model
clfd = DecisionTreeClassifier(criterion ="entropy", max_depth = 4)
start_time = time.time()
clfd.fit(x_train, y_train.values.ravel())
end_time = time.time()
print("Training time: ", end_time-start_time)
# Out:
# Training time:  0.01493692398071289

# %%
# Time taken to test the model
start_time = time.time()
y_test_pred = clfd.predict(x_train)
end_time = time.time()
print("Testing time: ", end_time-start_time)
# Out:
# Testing time:  0.001741170883178711

# %%
# Hyperparameter Tuning for Decision Tree using Optuna
def objective(trial):
    dt_max_depth = trial.suggest_int('dt_max_depth', 2, 32, log=False)
    dt_max_features = trial.suggest_int('dt_max_features', 2, 5, log=False)
    classifier_obj = DecisionTreeClassifier(max_features=dt_max_features, max_depth=dt_max_depth)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
# start the optimization process
study_dt = optuna.create_study(direction='maximize')
study_dt.optimize(objective, n_trials=30)
print(study_dt.best_trial)
# Out:
# [I 2024-02-04 21:26:25,133] A new study created in memory with name: no-name-4853774b-7723-45ae-8681-3d3cf4b90740
# [I 2024-02-04 21:26:25,151] Trial 0 finished with value: 0.9941783540619211 and parameters: {'dt_max_depth': 13, 'dt_max_features': 3}. Best is trial 0 with value: 0.9941783540619211.
# [I 2024-02-04 21:26:25,161] Trial 1 finished with value: 0.9371526858957396 and parameters: {'dt_max_depth': 2, 'dt_max_features': 4}. Best is trial 0 with value: 0.9941783540619211.
# [I 2024-02-04 21:26:25,179] Trial 2 finished with value: 0.9941783540619211 and parameters: {'dt_max_depth': 16, 'dt_max_features': 3}. Best is trial 0 with value: 0.9941783540619211.
# [I 2024-02-04 21:26:25,202] Trial 3 finished with value: 0.9944429743318338 and parameters: {'dt_max_depth': 30, 'dt_max_features': 4}. Best is trial 3 with value: 0.9944429743318338.
# [I 2024-02-04 21:26:25,212] Trial 4 finished with value: 0.9511775602011114 and parameters: {'dt_max_depth': 6, 'dt_max_features': 2}. Best is trial 3 with value: 0.9944429743318338.
# [I 2024-02-04 21:26:25,229] Trial 5 finished with value: 0.9939137337920084 and parameters: {'dt_max_depth': 21, 'dt_max_features': 3}. Best is trial 3 with value: 0.9944429743318338.
# [I 2024-02-04 21:26:25,241] Trial 6 finished with value: 0.9916644614977508 and parameters: {'dt_max_depth': 17, 'dt_max_features': 2}. Best is trial 3 with value: 0.9944429743318338.
# [I 2024-02-04 21:26:25,256] Trial 7 finished with value: 0.978433448002117 and parameters: {'dt_max_depth': 6, 'dt_max_features': 3}. Best is trial 3 with value: 0.9944429743318338.
# [I 2024-02-04 21:26:25,283] Trial 8 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 23, 'dt_max_features': 5}. Best is trial 8 with value: 0.9947075946017465.
# [I 2024-02-04 21:26:25,302] Trial 9 finished with value: 0.9862397459645409 and parameters: {'dt_max_depth': 6, 'dt_max_features': 5}. Best is trial 8 with value: 0.9947075946017465.
# [I 2024-02-04 21:26:25,336] Trial 10 finished with value: 0.9948399047367028 and parameters: {'dt_max_depth': 27, 'dt_max_features': 5}. Best is trial 10 with value: 0.9948399047367028.
# [I 2024-02-04 21:26:25,372] Trial 11 finished with value: 0.9948399047367028 and parameters: {'dt_max_depth': 27, 'dt_max_features': 5}. Best is trial 10 with value: 0.9948399047367028.
# [I 2024-02-04 21:26:25,414] Trial 12 finished with value: 0.9949722148716592 and parameters: {'dt_max_depth': 32, 'dt_max_features': 5}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,454] Trial 13 finished with value: 0.9928552527123577 and parameters: {'dt_max_depth': 32, 'dt_max_features': 4}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,531] Trial 14 finished with value: 0.9949722148716592 and parameters: {'dt_max_depth': 24, 'dt_max_features': 5}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,579] Trial 15 finished with value: 0.9948399047367028 and parameters: {'dt_max_depth': 23, 'dt_max_features': 5}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,607] Trial 16 finished with value: 0.9949722148716592 and parameters: {'dt_max_depth': 28, 'dt_max_features': 4}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,640] Trial 17 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 32, 'dt_max_features': 5}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,667] Trial 18 finished with value: 0.9937814236570521 and parameters: {'dt_max_depth': 24, 'dt_max_features': 4}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,700] Trial 19 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 20, 'dt_max_features': 5}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,727] Trial 20 finished with value: 0.9939137337920084 and parameters: {'dt_max_depth': 13, 'dt_max_features': 4}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,753] Trial 21 finished with value: 0.9943106641968775 and parameters: {'dt_max_depth': 28, 'dt_max_features': 4}. Best is trial 12 with value: 0.9949722148716592.
# [I 2024-02-04 21:26:25,783] Trial 22 finished with value: 0.9951045250066155 and parameters: {'dt_max_depth': 29, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:25,814] Trial 23 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 25, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:25,844] Trial 24 finished with value: 0.9945752844667901 and parameters: {'dt_max_depth': 30, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:25,875] Trial 25 finished with value: 0.9949722148716592 and parameters: {'dt_max_depth': 30, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:25,905] Trial 26 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 20, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:25,936] Trial 27 finished with value: 0.9928552527123577 and parameters: {'dt_max_depth': 26, 'dt_max_features': 4}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:25,974] Trial 28 finished with value: 0.9945752844667901 and parameters: {'dt_max_depth': 29, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# [I 2024-02-04 21:26:26,010] Trial 29 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 32, 'dt_max_features': 5}. Best is trial 22 with value: 0.9951045250066155.
# FrozenTrial(number=22, state=TrialState.COMPLETE, values=[0.9951045250066155], datetime_start=datetime.datetime(2024, 2, 4, 21, 26, 25, 754217), datetime_complete=datetime.datetime(2024, 2, 4, 21, 26, 25, 783553), params={'dt_max_depth': 29, 'dt_max_features': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'dt_max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'dt_max_features': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=22, value=None)

# %%
# Training the Decision Tree model with the best parameters
dt = DecisionTreeClassifier(max_features=study_dt.best_trial.params['dt_max_features'], max_depth=study_dt.best_trial.params['dt_max_depth'])
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=29, max_features=5)

# %% [markdown]
# #### Model Evaluation

# %%
# Model Performance Metrics
dt_train, dt_test = dt.score(x_train, y_train), dt.score(x_test, y_test)
print(f"Train Score: {dt_train}")
print(f"Test Score: {dt_test}")
# Out:
# Train Score: 0.9985822842236588
# Test Score: 0.9951045250066155

# %%
# Cross-Validation why we use cross-validation?
# Cross-validation is a resampling procedure used to evaluate machine learning models on a limited data sample.
# The goal of cross-validation is to test the model’s ability to predict new data that was not used in estimating it
# we will use cross-validation to evaluate the performance of our model
# we will use 10 folds for cross-validation
# we will use the accuracy metric to evaluate the performance of our model

scores = cross_val_score(dt, x_train, y_train, cv=10, scoring='accuracy')
print(f"Cross-Validation Accuracy: {np.mean(scores)}")
# Out:
# Cross-Validation Accuracy: 0.9921174803822078

# %%
# Confusion Matrix and Classification Report why we use these metrics?
# Confusion matrix is used to evaluate the performance of a classification model
# Classification report is used to measure the quality of predictions from a classification algorithm
y_pred = dt.predict(x_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# F1 Score
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1}")
# Out:
# [[3503   13]
#  [  24 4018]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3516
#            1       1.00      0.99      1.00      4042
#
#     accuracy                           1.00      7558
#    macro avg       0.99      1.00      1.00      7558
# weighted avg       1.00      1.00      1.00      7558
#
# F1 Score: 0.9954168215037781

# %% [markdown]
# #### Summary Table

# %%
# Creating a summary table of model performance
data = [["Decision Tree", dt_train, dt_test, np.mean(scores), f1]]
col_names = ["Model", "Train Score", "Test Score", "CV Accuracy", "F1 Score"]
print(tabulate(data, headers=col_names, tablefmt="fancy_grid"))
# Out:
# ╒═══════════════╤═══════════════╤══════════════╤═══════════════╤════════════╕
# │ Model         │   Train Score │   Test Score │   CV Accuracy │   F1 Score │
# ╞═══════════════╪═══════════════╪══════════════╪═══════════════╪════════════╡
# │ Decision Tree │      0.998582 │     0.995105 │      0.992117 │   0.995417 │
# ╘═══════════════╧═══════════════╧══════════════╧═══════════════╧════════════╛

# %% [markdown]
# #### Saving the model

# %%
# Save the model to a file
model_filename = 'decision_tree_model.joblib'
dump(dt, model_filename)
print(f"Model saved to {model_filename}")
# Out:
# Model saved to decision_tree_model.joblib

# %% [markdown]
# #### Load the model

# %%
# Load the model from the file
loaded_model = load(model_filename)
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
from scapy.all import IP, TCP, UDP, sniff
import numpy as np
import joblib
from collections import defaultdict, Counter

def encode_protocol(packet):
    protocol_mapping = {'icmp': 0, 'tcp': 1, 'udp': 2}
    if IP in packet:
        if packet[IP].proto == 1:
            return protocol_mapping['icmp']
        elif packet[IP].proto == 6:
            return protocol_mapping['tcp']
        elif packet[IP].proto == 17:
            return protocol_mapping['udp']
    return -1

class ConnectionTracker:
    def __init__(self):
        self.connections = defaultdict(lambda: {'src_bytes': 0, 'dst_bytes': 0, 'dst_host_srv_count': 0, 'dst_host_same_srv_rate': 0})
        self.dst_host_counts = Counter()

    def update_connection(self, packet):
        if IP in packet and (TCP in packet or UDP in packet):
            src = (packet[IP].src, packet[TCP].sport if TCP in packet else packet[UDP].sport)
            dst = (packet[IP].dst, packet[TCP].dport if TCP in packet else packet[UDP].dport)
            key = src + dst

            if packet[IP].src == src[0]:
                self.connections[key]['src_bytes'] += len(packet)
            else:
                self.connections[key]['dst_bytes'] += len(packet)

            # Update counts for dst_host_srv_count
            self.dst_host_counts[dst] += 1
            for conn_key in self.connections:
                if conn_key[2:] == dst:
                    self.connections[conn_key]['dst_host_srv_count'] = self.dst_host_counts[dst]

            # Calculate dst_host_same_srv_rate
            total_connections_to_dst_host = sum(1 for k in self.connections if k[2] == dst[0])
            if total_connections_to_dst_host > 0:
                same_srv_rate = self.dst_host_counts[dst] / total_connections_to_dst_host
                for conn_key in self.connections:
                    if conn_key[2] == dst[0]:
                        self.connections[conn_key]['dst_host_same_srv_rate'] = same_srv_rate

class NetworkTrafficAnalysis:
    def __init__(self, model_path):
        self.model = joblib.load(model_path)
        self.tracker = ConnectionTracker()

    def process_packet(self, packet):
        if IP not in packet:
            return
        
        protocol_type = encode_protocol(packet)
        self.tracker.update_connection(packet)
        
        for key, stats in self.tracker.connections.items():
            features = np.array([[protocol_type, stats['src_bytes'], stats['dst_bytes'], stats['dst_host_srv_count'], stats['dst_host_same_srv_rate']]])
            prediction = self.model.predict(features)[0]
            traffic_type = "Anomaly/Attack" if prediction == 1 else "Normal"
            print(f"Connection: {key}, Traffic Classification: {traffic_type}, " +
                  f"Features: protocol_type={protocol_type}, src_bytes={stats['src_bytes']}, " +
                  f"dst_bytes={stats['dst_bytes']}, dst_host_srv_count={stats['dst_host_srv_count']}, " +
                  f"dst_host_same_srv_rate={stats['dst_host_same_srv_rate']}")

    def start_capture(self):
        print("Starting packet capture. Press Ctrl+C to stop.")
        sniff(prn=self.process_packet, store=False)

if __name__ == "__main__":
    model_path = '/Users/maryam/ML-IDS/decision_tree_model.joblib'
    analysis_system = NetworkTrafficAnalysis(model_path)
    analysis_system.start_capture()
# Out:
# Starting packet capture. Press Ctrl+C to stop.
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Anomaly/Attack, Features: protocol_type=1, src_bytes=69, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Anomaly/Attack, Features: protocol_type=1, src_bytes=69, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Anomaly/Attack, Features: protocol_type=1, src_bytes=54, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=152, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Anomaly/Attack, Features: protocol_type=1, src_bytes=54, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=152, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=112, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=112, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=218, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=436, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=654, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Anomaly/Attack, Features: protocol_type=1, src_bytes=66, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=156, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.3333333333333333
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=156, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.25
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.25
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.25
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.25
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.2
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.2
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.2
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.2
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.2
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=206, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=275, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=283, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.16666666666666666
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=275, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=337, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=358, dst_bytes=0, dst_host_srv_count=5, dst_host_same_srv_rate=5.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=337, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.5
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=358, dst_bytes=0, dst_host_srv_count=5, dst_host_same_srv_rate=5.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=566, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=412, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=6.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=566, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=90, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=1, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=412, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=6.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=566, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=166, dst_bytes=0, dst_host_srv_count=2, dst_host_same_srv_rate=2.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=101, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=222, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=0.6666666666666666
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=248, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=4, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=0.6666666666666666
# ...
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 13782, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 20977, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 47037, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 47037), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 13782), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=109, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 20977), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=97, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58312, '52.123.159.142', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1281, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('52.123.159.142', 443, '172.20.10.4', 58312), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=6906, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 52251, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=218, dst_bytes=0, dst_host_srv_count=5, dst_host_same_srv_rate=2.5
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=922, dst_bytes=0, dst_host_srv_count=13, dst_host_same_srv_rate=13.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1264, dst_bytes=0, dst_host_srv_count=10, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=498, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=6.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=303, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=666, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=744, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 13782, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 20977, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 47037, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 47037), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 13782), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=109, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 20977), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=97, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58312, '52.123.159.142', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1281, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('52.123.159.142', 443, '172.20.10.4', 58312), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=6906, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 52251, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=436, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=3.0
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=922, dst_bytes=0, dst_host_srv_count=13, dst_host_same_srv_rate=13.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1264, dst_bytes=0, dst_host_srv_count=10, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=498, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=6.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=303, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=7, dst_host_same_srv_rate=3.5
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=666, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=744, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 13782, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 20977, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 47037, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 47037), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 13782), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=109, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 20977), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=97, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58312, '52.123.159.142', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1281, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('52.123.159.142', 443, '172.20.10.4', 58312), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=6906, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 52251, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=654, dst_bytes=0, dst_host_srv_count=7, dst_host_same_srv_rate=3.5
# Connection: ('172.20.10.4', 57348, '20.198.119.84', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=922, dst_bytes=0, dst_host_srv_count=13, dst_host_same_srv_rate=13.0
# Connection: ('20.198.119.84', 443, '172.20.10.4', 57348), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1264, dst_bytes=0, dst_host_srv_count=10, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 57342, '52.112.238.132', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=498, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=6.0
# Connection: ('52.112.238.132', 443, '172.20.10.4', 57342), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=303, dst_bytes=0, dst_host_srv_count=3, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58283, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=8, dst_host_same_srv_rate=4.0
# Connection: ('172.20.10.1', 5353, '224.0.0.251', 5353), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=137, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('20.88.154.184', 443, '172.20.10.4', 58278), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=666, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58278, '20.88.154.184', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=744, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('172.20.10.4', 4301, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 36777, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 34234, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=90, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 36777), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=197, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 4301), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=245, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 34234), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=133, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 13782, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 20977, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 47037, '172.20.10.1', 53), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=6, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 47037), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=81, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 13782), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=109, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.1', 53, '172.20.10.4', 20977), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=97, dst_bytes=0, dst_host_srv_count=1, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 58312, '52.123.159.142', 443), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=1281, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=9.0
# Connection: ('52.123.159.142', 443, '172.20.10.4', 58312), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=6906, dst_bytes=0, dst_host_srv_count=9, dst_host_same_srv_rate=1.0
# Connection: ('172.20.10.4', 52251, '239.255.255.250', 1900), Traffic Classification: Normal, Features: protocol_type=2, src_bytes=872, dst_bytes=0, dst_host_srv_count=8, dst_host_same_srv_rate=4.0
